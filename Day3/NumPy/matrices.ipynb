# %% [markdown]
# ### Numpy using Matrices

# %%
import numpy as np

# %%
mat_a = np.asmatrix([[1, 2], [3, 4]])
mat_a
# Out:
# matrix([[1, 2],
#         [3, 4]])

# %%
mat_a.size
# Out:
# 4

# %%
mat_b = np.asmatrix('1, 2; 3, 4')
mat_b
# Out:
# matrix([[1, 2],
#         [3, 4]])

# %%
mat_c = np.matrix('1, 2; 3, 4; 5, 6')
mat_c
# Out:
# matrix([[1, 2],
#         [3, 4],
#         [5, 6]])

# %%
mat_c.ndim
# Out:
# 2
