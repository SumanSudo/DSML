# %% [markdown]
# ## Basic Usuage

# %% [markdown]
# ### Importing Pandas
# To import the pandas on any python projects, use `import pandas` command. After the import, we simply can check the pandas version installed using the command `pandas.__version__`.

# %%
import pandas

# %%
pandas.__version__
# Out:
# '2.3.3'

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# ### Creating Pandas Series

# %% [markdown]
# #### Using NumPy Arrays

# %% [markdown]
# ##### Creating Series without index from array

# %%
import numpy as np

# %%
array_a =  np.array(["I", "Love", "Python"])

# %%
series_from_array = pd.Series(array_a)
series_from_array
# Out:
# 0         I
# 1      Love
# 2    Python
# dtype: object

# %%
type(series_from_array)
# Out:
# pandas.core.series.Series

# %%
series_from_array[2]
# Out:
# 'Python'

# %% [markdown]
# ##### Creating Series with Index from array

# %%
series_from_array_index = pd.Series(array_a, index=['a', 'b', 'c'])
series_from_array_index
# Out:
# a         I
# b      Love
# c    Python
# dtype: object

# %%
series_from_array_index['c']
# Out:
# 'Python'

# %% [markdown]
# *Note: Series can be created from Python List similar to the above by passing the list as an argument to `pd.Series()`.*

# %% [markdown]
# #### Using Python Dictionary

# %%
dict_a = {'Ram':90, 'Hari':86.5, 'Gita':87.3}

# %%
series_from_dict = pd.Series(dict_a)
series_from_dict
# Out:
# Ram     90.0
# Hari    86.5
# Gita    87.3
# dtype: float64

# %%
series_from_dict.index
# Out:
# Index(['Ram', 'Hari', 'Gita'], dtype='object')

# %%
series_from_dict.values
# Out:
# array([90. , 86.5, 87.3])

# %% [markdown]
# ### Creating Python DataFrames

# %% [markdown]
# #### Using Python List

# %%
list_a = ['Python', 'Ruby','Rust','Java','PHP']

# %%
dataframe_from_list = pd.DataFrame(list_a)

# %%
dataframe_from_list
# Out:
#         0
# 0  Python
# 1    Ruby
# 2    Rust
# 3    Java
# 4     PHP

# %% [markdown]
# ##### *to create a column name, use the following*

# %%
dataframe_from_list_col_name = pd.DataFrame(list_a, columns=["Programming Languages"])
dataframe_from_list_col_name
# Out:
#   Programming Languages
# 0                Python
# 1                  Ruby
# 2                  Rust
# 3                  Java
# 4                   PHP

# %%
dataframe_from_list_col_name["Programming Languages"][2]
# Out:
# 'Rust'

# %%
dataframe_from_list_col_name["Programming Languages"].iloc[2] # iloc -> integer location
# Out:
# 'Rust'

# %% [markdown]
# ##### Creating DataFrame from List of list

# %%
list_b = [["Ram Thapa", "Koteshwor"],["Nitesh Rai", "London"]]

# %%
data_frame = pd.DataFrame(list_b, columns=["Name", "Address"])

# %%
data_frame
# Out:
#          Name    Address
# 0   Ram Thapa  Koteshwor
# 1  Nitesh Rai     London

# %% [markdown]
# ##### Creating DataFrame from List of list

# %%
dict_b = {"Name": ["Rita Thapa", "Nitesh Jung Kuwar"], "Address":["kalanki", "surkhet"]}

# %%
data_frames_from_dict = pd.DataFrame(dict_b)
data_frames_from_dict
# Out:
#                 Name  Address
# 0         Rita Thapa  kalanki
# 1  Nitesh Jung Kuwar  surkhet

# %%
# create a row label
dataframe_from_dict_lables = pd.DataFrame(dict_b, index=["A", "B"])

# %%
dataframe_from_dict_lables
# Out:
#                 Name  Address
# A         Rita Thapa  kalanki
# B  Nitesh Jung Kuwar  surkhet

# %% [markdown]
# ### Indexing and Slicing Pandas Series

# %% [markdown]
# #### Indexing by Item name

# %%
series_from_array_index
# Out:
# a         I
# b      Love
# c    Python
# dtype: object

# %%
series_from_array_index['a']
# Out:
# 'I'

# %%
series_from_array_index['a':'c']
# Out:
# a         I
# b      Love
# c    Python
# dtype: object

# %% [markdown]
# #### Indexing by number (Positional value)

# %%
series_from_array_index[0]
# Out:
# C:\Users\victus\AppData\Local\Temp\ipykernel_10520\246369587.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   series_from_array_index[0]
# 'I'

# %%
series_from_array_index[0:2]
# Out:
# a       I
# b    Love
# dtype: object

# %% [markdown]
# ### Reading a csv file in Pandas
# https://www.kaggle.com/datasets/leiladana/titanic?resource=download

# %%
dataset = pd.read_csv("titanic_train.csv")

# %%
dataset.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
dataset.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dataset.describe(include='object')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
type(dataset['Age'])
# Out:
# pandas.core.series.Series

# %%
dataset['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %% [markdown]
# In the above result, one of the entry in the **age** column in **nan** that specifies the entry is **not a number**. In Machine Learning, as we need to deal with calculations, those should be handled using appropriate mechanisms. Some of the ideas to deal with **nan** values in dataset are as follows:
# - Drop rows or columns with missing values.
# - Fill the missing values with constant or scalar values.
# - Fill the missing values with aggregated values like mean, median and mode of the particular column.
# - Fill the missing value with previous or next value (forward or backward fill)

# %%
dataset.isna() # is not avaiable?
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False  False     False
# 4    False   True     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
dataset.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False  False     False
# 4    False   True     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
dataset['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
dataset['Age'].value_counts(dropna=False)
# Out:
# Age
# NaN      177
# 24.00     30
# 22.00     27
# 18.00     26
# 28.00     25
#         ...
# 36.50      1
# 55.50      1
# 0.92       1
# 23.50      1
# 74.00      1
# Name: count, Length: 89, dtype: int64

# %%
dataset.shape
# Out:
# (891, 12)

# %%
dataset.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
